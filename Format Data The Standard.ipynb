# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pytz import timezone

# %%
df = pd.read_csv('/Users/tomfoolery/Documents/Study/NLP_Project/scraping/the_standard/data_with_content.csv')

# %%
df.head()
# Out:
#                                             headline        date  time  view  \
# 0  ซักซ้อมเสมือนจริง พิธีพลีกรรมตักน้ำศักดิ์สิทธิ...  04.04.2019   NaN   96K
# 1  วีซ่าเผย E-Payment เติบโตต่อเนื่อง กลุ่มตัวอย่...  03.04.2019   NaN   62K
# 2  รมว.คลัง-ผู้ว่าแบงก์ชาติชื่นมื่น ปิดฉากประชุมธ...  05.04.2019   NaN   41K
# 3  ส.ส. เมืองผู้ดีลงมติให้รัฐบาลเดินหน้าเจรจาขอยื...  04.04.2019   NaN  103K
# 4  จับตา Central.co.th ความหวังกลุ่มเซ็นทรัลดันออ...  02.04.2019   NaN  191K
#
#    like       share  comment  category  \
# 0   NaN  Loading...      NaN  Thailand
# 1   NaN  Loading...      NaN  Business
# 2   NaN  Loading...      NaN  Business
# 3   NaN  Loading...      NaN     World
# 4   NaN  Loading...      NaN  Business
#
#                                                  tag  \
# 0            อัศวิน ขวัญเมือง,พระราชพิธีบรมราชาภิเษก
# 1                    e-payment,visa,Cashless Society
# 2  กระทรวงการคลัง,แบงก์ชาติ,อภิศักดิ์ ตันติวรวงศ์...
# ...

# %%
def applyview(x):
    if 'K' in x:
        temp = x[:-1:]
        temp = int(temp.replace(',',''))*1000
    else:
        temp = x
    return temp
df['view'] = df['view'].apply(applyview)

# %%
df.iloc[np.argmax(df['view'])]
# Out:
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:56: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   return getattr(obj, method)(*args, **kwds)
# headline    เด็กหญิงไทยวัย 11 ปี แต่งงานเป็นเมียคนที่ 3 ขอ...
# date                                               02.07.2018
# time                                                      NaN
# view                                                304443000
# like                                                      NaN
# share                                              Loading...
# comment                                                   NaN
# category                                       World,Thailand
# tag                   สิทธิมนุษยชน,สิทธิสตรี,ความจน,สิทธิเด็ก
# ...

# %%
def addDOW(x):
    days = ['MON','TUE','WED','THU','FRI','SAT','SUN']
    return days[datetime.strptime(x,'%d.%m.%Y').weekday()]

# %%
df['DOW'] = df['date'].apply(addDOW)

# %%
def add543(x):
    temp = x.split('.')
    temp[-1] = str(int(temp[-1])+543)
    return '/'.join(temp)

# %%
df['date'] = df['date'].apply(add543)

# %%
df['time'] = df['time'].apply(lambda x : None)
df['like'] = df['like'].apply(lambda x : None)
df['comment'] = df['comment'].apply(lambda x : None)
df['share'] = df['share'].apply(lambda x : None)

# %%
df.to_csv('the_standard_data.csv',index=False)

# %%
df
# Out:
#                                                headline        date  time  \
# 0     ซักซ้อมเสมือนจริง พิธีพลีกรรมตักน้ำศักดิ์สิทธิ...  04/04/2562  None
# 1     วีซ่าเผย E-Payment เติบโตต่อเนื่อง กลุ่มตัวอย่...  03/04/2562  None
# 2     รมว.คลัง-ผู้ว่าแบงก์ชาติชื่นมื่น ปิดฉากประชุมธ...  05/04/2562  None
# 3     ส.ส. เมืองผู้ดีลงมติให้รัฐบาลเดินหน้าเจรจาขอยื...  04/04/2562  None
# 4     จับตา Central.co.th ความหวังกลุ่มเซ็นทรัลดันออ...  02/04/2562  None
# 5     วาฬตั้งท้องเกยตื้นตายริมชายหาดอิตาลี พบขยะพลาส...  02/04/2562  None
# 6     ภัยเเล้งมาเยือน 4 จังหวัด ปภ. ประสานแก้ปัญหา จ...  02/04/2562  None
# 7     รองโฆษกพลังประชารัฐขอบางกลุ่มหยุดเคลื่อนไหวการ...  02/04/2562  None
# 8     5 ปี รายการเดินหน้าประเทศไทย สถานีโทรทัศน์สูญเ...  29/03/2562  None
# 9     คิง เพาเวอร์ ไทย อวดโฉมมรดกไทยสู่สายตาชาวโลกผ่...  30/03/2562  None
# 10    ‘ยอดแสนไกล-รถถัง’ สองนักชกไทยคว้าชัยในศึก ONE ...  31/03/2562  None
# 11    วิกฤตฝุ่น pm2.5 เชียงใหม่ ถ่ายจากจุดชมวิวดอยสุเทพ  30/03/2562  None
# ...
